# %%
import pandas as pd

# %%
spotify = pd.read_csv("../data/spotify_songs.csv")

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
'''
track_id                     Song unique ID
track_name                   Song Name
track_artist                 Song Artist
track_popularity             Song Popularity (0-100) where higher is better
                             he popularity is calculated by algorithm and is based, in the most part, on 
                             the total number of plays the track has had and how recent those plays are.
                             Generally speaking, songs that are being played a lot now will have a higher popularity 
                             than songs that were played a lot in the past.
track_album_id               Album unique ID
track_album_name             Song album name
track_album_release_date     Date when album released
playlist_name                Name of playlist
playlist_id                  Playlist ID
playlist_genre               Playlist genre
playlist_subgenre            Playlist subgenre
danceability (0-1)           Danceability describes how suitable a track is for dancing based on a 
                             combination of musical elements including tempo, rhythm stability, beat strength,  
                             and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
energy (0-1)                 Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity.  
                             Typically, energetic tracks feel fast, loud, and noisy. 
                             For example, death metal has high energy, while a Bach prelude scores low on the scale. 
                             Perceptual features contributing to this attribute include dynamic range, perceived loudness, 
                             timbre, onset rate, and general entropy.
key                          The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation
                             0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
loudness                     The overall loudness of a track in decibels (dB). 
                             Loudness values are averaged across the entire track and are useful for comparing relative loudness
                             of tracks. Loudness is the quality of a sound that is the primary psychological correlate 
                             of physical strength (amplitude). Values typical range between -60 and 0 db.
mode                         Mode indicates the modality (major or minor) of a track, the type of scale 
                             from which its melodic content is derived. Major is represented by 1 and minor is 0.
speechiness                  Speechiness detects the presence of spoken words in a track. 
                             The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), 
                             the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably 
                             made entirely of spoken words. Values between 0.33 and 0.66 describe tracks 
                             that may contain both music and speech, either in sections or layered, 
                             including such cases as rap music. Values below 0.33 most likely represent music and 
                             other non-speech-like tracks.
acousticness                 A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 
                             1.0 represents high confidence the track is acoustic.
instrumentalness             Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental 
                             in this context. Rap or spoken word tracks are clearly "vocal". 
                             The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal
                             content. Values above 0.5 are intended to represent instrumental tracks, 
                             but confidence is higher as the value approaches 1.0.
liveness                     Detects the presence of an audience in the recording. 
                             Higher liveness values represent an increased probability that the track was performed live. 
                             A value above 0.8 provides strong likelihood that the track is live.
valence (0-1)                A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. 
                             Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), 
                             while tracks with low valence sound more negative (e.g. sad, depressed, angry).
tempo                        The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, 
                             tempo is the speed or pace of a given piece 
                             and derives directly from the average beat duration.
duration_ms                  Duration of song in milliseconds
'''

# %%
spotify[spotify["track_popularity"]==98]
# Out:
#                      track_id       track_name track_artist  track_popularity  \
# 687    7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 711    2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 716    0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 1300   2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 1301   21jGcNKet2qwijlDFuPiPb          Circles  Post Malone                98
# 1605   0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 4713   0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 5508   0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 9018   0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 11113  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 11184  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 17595  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 18299  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 18307  0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 18308  2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 18330  21jGcNKet2qwijlDFuPiPb          Circles  Post Malone                98
# 18756  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 19265  2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 19707  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 19715  0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 19716  2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 19740  21jGcNKet2qwijlDFuPiPb          Circles  Post Malone                98
# 20252  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 21384  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 21542  2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 21571  0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 22933  0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 23100  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 23103  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 23107  2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 23109  21jGcNKet2qwijlDFuPiPb          Circles  Post Malone                98
# 30197  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 30201  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 30203  0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 30207  2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 30209  21jGcNKet2qwijlDFuPiPb          Circles  Post Malone                98
#
#                track_album_id                       track_album_name  \
# 687    7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 711    3nR9B40hYLKLcR0Eph3Goc                               Memories
# 716    2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 1300   3nR9B40hYLKLcR0Eph3Goc                               Memories
# 1301   4g1ZRSobMefqF6nelkgibi                   Hollywood's Bleeding
# 1605   2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 4713   2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 5508   52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 9018   52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 11113  7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 11184  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 17595  7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 18299  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 18307  2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 18308  3nR9B40hYLKLcR0Eph3Goc                               Memories
# 18330  4g1ZRSobMefqF6nelkgibi                   Hollywood's Bleeding
# 18756  7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 19265  3nR9B40hYLKLcR0Eph3Goc                               Memories
# 19707  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 19715  2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 19716  3nR9B40hYLKLcR0Eph3Goc                               Memories
# 19740  4g1ZRSobMefqF6nelkgibi                   Hollywood's Bleeding
# 20252  7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 21384  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 21542  3nR9B40hYLKLcR0Eph3Goc                               Memories
# 21571  2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 22933  2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 23100  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 23103  7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 23107  3nR9B40hYLKLcR0Eph3Goc                               Memories
# 23109  4g1ZRSobMefqF6nelkgibi                   Hollywood's Bleeding
# 30197  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
# 30201  7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 30203  2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 30207  3nR9B40hYLKLcR0Eph3Goc                               Memories
# 30209  4g1ZRSobMefqF6nelkgibi                   Hollywood's Bleeding
#
#       track_album_release_date  \
# 687                 2019-11-07
# 711                 2019-09-20
# 716                 2019-11-29
# 1300                2019-09-20
# 1301                2019-09-06
# 1605                2019-11-29
# 4713                2019-11-29
# 5508                2019-12-06
# 9018                2019-12-06
# 11113               2019-11-07
# 11184               2019-12-06
# 17595               2019-11-07
# 18299               2019-12-06
# 18307               2019-11-29
# 18308               2019-09-20
# 18330               2019-09-06
# 18756               2019-11-07
# 19265               2019-09-20
# 19707               2019-12-06
# 19715               2019-11-29
# 19716               2019-09-20
# 19740               2019-09-06
# 20252               2019-11-07
# 21384               2019-12-06
# 21542               2019-09-20
# 21571               2019-11-29
# 22933               2019-11-29
# 23100               2019-12-06
# 23103               2019-11-07
# 23107               2019-09-20
# 23109               2019-09-06
# 30197               2019-12-06
# 30201               2019-11-07
# 30203               2019-11-29
# 30207               2019-09-20
# 30209               2019-09-06
#
#                                            playlist_name  \
# 687                                          Todo Éxitos
# 711                                          Todo Éxitos
# 716                                          Todo Éxitos
# 1300     Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1301     Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop
# 1605   post-teen alternative, indie, pop (large variety)
# 4713                                   indie poptimism🕺🏻
# 5508                                           RapCaviar
# 9018                    GTA San Andreas Radio Los Santos
# 11113                                        Trap 2020 🔥
# 11184                                     Trap Americana
# 17595                                      Latin Pop VIP
# 18299     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 18307     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 18308     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 18330     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 18756                                    Baila Reggaeton
# 19265                                     Verano Forever
# 19707     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 19715     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 19716     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 19740     2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥
# 20252                               Urbano: Latino Vibes
# 21384                                New Hip Hop‏‏​​   ‍
# 21542                           Most Popular 2020 TOP 50
# 21571                           Most Popular 2020 TOP 50
# 22933                                      Pop Hits 2020
# 23100  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23103  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23107  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 23109  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30197  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30201  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30203  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30207  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
# 30209  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Po...
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 687    2ji5tRQVfnhaX1w9FhmSzk            pop  ...   2    -3.280     1
# 711    2ji5tRQVfnhaX1w9FhmSzk            pop  ...  11    -7.209     1
# 716    2ji5tRQVfnhaX1w9FhmSzk            pop  ...   1    -4.075     1
# 1300   46Cl6dmeiylK6TRGXr7hHe            pop  ...  11    -7.209     1
# 1301   46Cl6dmeiylK6TRGXr7hHe            pop  ...   0    -3.497     1
# 1605   1y42gwI5cuwjBslPyQNfqb            pop  ...   1    -4.075     1
# 4713   6MQeEHHDs6HQkN5Dlj3oKo            pop  ...   1    -4.075     1
# 5508   37i9dQZF1DX0XUsuxWHRQd            rap  ...  10    -6.687     0
# 9018   6m0BqpJfSP2m5xCOFjDRHw            rap  ...  10    -6.687     0
# 11113  37DFLy7lqF3qiR99Ss2ZGR            rap  ...   2    -3.280     1
# 11184  7tkgK1tm9hYkWp7EFyOcAr            rap  ...  10    -6.687     0
# 17595  37i9dQZF1DX1QnNyJOBQBv          latin  ...   2    -3.280     1
# 18299  4JkkvMpVl4lSioqQjeAL0q          latin  ...  10    -6.687     0
# 18307  4JkkvMpVl4lSioqQjeAL0q          latin  ...   1    -4.075     1
# 18308  4JkkvMpVl4lSioqQjeAL0q          latin  ...  11    -7.209     1
# 18330  4JkkvMpVl4lSioqQjeAL0q          latin  ...   0    -3.497     1
# 18756  37i9dQZF1DWY7IeIP1cdjF          latin  ...   2    -3.280     1
# 19265  37i9dQZF1DXdnGF35OawbN          latin  ...  11    -7.209     1
# 19707  4JkkvMpVl4lSioqQjeAL0q          latin  ...  10    -6.687     0
# 19715  4JkkvMpVl4lSioqQjeAL0q          latin  ...   1    -4.075     1
# 19716  4JkkvMpVl4lSioqQjeAL0q          latin  ...  11    -7.209     1
# 19740  4JkkvMpVl4lSioqQjeAL0q          latin  ...   0    -3.497     1
# 20252  0VsVywryrqLhHmsVFVcOAg          latin  ...   2    -3.280     1
# 21384  5WNUX6jisX0NRlVDTm6RDd            r&b  ...  10    -6.687     0
# 21542  1fqkbjEACMlekdddm5aobE            r&b  ...  11    -7.209     1
# 21571  1fqkbjEACMlekdddm5aobE            r&b  ...   1    -4.075     1
# 22933  5TDtuKDbOhrfW7C58XnriZ            r&b  ...   1    -4.075     1
# 23100  3xMQTDLOIGvj3lWH5e5x6F            r&b  ...  10    -6.687     0
# 23103  3xMQTDLOIGvj3lWH5e5x6F            r&b  ...   2    -3.280     1
# 23107  3xMQTDLOIGvj3lWH5e5x6F            r&b  ...  11    -7.209     1
# 23109  3xMQTDLOIGvj3lWH5e5x6F            r&b  ...   0    -3.497     1
# 30197  3xMQTDLOIGvj3lWH5e5x6F            edm  ...  10    -6.687     0
# 30201  3xMQTDLOIGvj3lWH5e5x6F            edm  ...   2    -3.280     1
# 30203  3xMQTDLOIGvj3lWH5e5x6F            edm  ...   1    -4.075     1
# 30207  3xMQTDLOIGvj3lWH5e5x6F            edm  ...  11    -7.209     1
# 30209  3xMQTDLOIGvj3lWH5e5x6F            edm  ...   0    -3.497     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 687         0.2980       0.29500          0.000134    0.0574    0.574
# 711         0.0546       0.83700          0.000000    0.0822    0.575
# 716         0.0629       0.00147          0.000209    0.0938    0.345
# 1300        0.0546       0.83700          0.000000    0.0822    0.575
# 1301        0.0395       0.19200          0.002440    0.0863    0.553
# 1605        0.0629       0.00147          0.000209    0.0938    0.345
# 4713        0.0629       0.00147          0.000209    0.0938    0.345
# 5508        0.0559       0.10400          0.000000    0.7900    0.642
# 9018        0.0559       0.10400          0.000000    0.7900    0.642
# 11113       0.2980       0.29500          0.000134    0.0574    0.574
# 11184       0.0559       0.10400          0.000000    0.7900    0.642
# 17595       0.2980       0.29500          0.000134    0.0574    0.574
# 18299       0.0559       0.10400          0.000000    0.7900    0.642
# 18307       0.0629       0.00147          0.000209    0.0938    0.345
# 18308       0.0546       0.83700          0.000000    0.0822    0.575
# 18330       0.0395       0.19200          0.002440    0.0863    0.553
# 18756       0.2980       0.29500          0.000134    0.0574    0.574
# 19265       0.0546       0.83700          0.000000    0.0822    0.575
# 19707       0.0559       0.10400          0.000000    0.7900    0.642
# 19715       0.0629       0.00147          0.000209    0.0938    0.345
# 19716       0.0546       0.83700          0.000000    0.0822    0.575
# 19740       0.0395       0.19200          0.002440    0.0863    0.553
# 20252       0.2980       0.29500          0.000134    0.0574    0.574
# 21384       0.0559       0.10400          0.000000    0.7900    0.642
# 21542       0.0546       0.83700          0.000000    0.0822    0.575
# 21571       0.0629       0.00147          0.000209    0.0938    0.345
# 22933       0.0629       0.00147          0.000209    0.0938    0.345
# 23100       0.0559       0.10400          0.000000    0.7900    0.642
# 23103       0.2980       0.29500          0.000134    0.0574    0.574
# 23107       0.0546       0.83700          0.000000    0.0822    0.575
# 23109       0.0395       0.19200          0.002440    0.0863    0.553
# 30197       0.0559       0.10400          0.000000    0.7900    0.642
# 30201       0.2980       0.29500          0.000134    0.0574    0.574
# 30203       0.0629       0.00147          0.000209    0.0938    0.345
# 30207       0.0546       0.83700          0.000000    0.0822    0.575
# 30209       0.0395       0.19200          0.002440    0.0863    0.553
#
#          tempo  duration_ms
# 687    101.085       200960
# 711     91.019       189486
# 716    171.017       201573
# 1300    91.019       189486
# 1301   120.042       215280
# 1605   171.017       201573
# 4713   171.017       201573
# 5508   116.971       196653
# 9018   116.971       196653
# 11113  101.085       200960
# 11184  116.971       196653
# 17595  101.085       200960
# 18299  116.971       196653
# 18307  171.017       201573
# 18308   91.019       189486
# 18330  120.042       215280
# 18756  101.085       200960
# 19265   91.019       189486
# 19707  116.971       196653
# 19715  171.017       201573
# 19716   91.019       189486
# 19740  120.042       215280
# 20252  101.085       200960
# 21384  116.971       196653
# 21542   91.019       189486
# 21571  171.017       201573
# 22933  171.017       201573
# 23100  116.971       196653
# 23103  101.085       200960
# 23107   91.019       189486
# 23109  120.042       215280
# 30197  116.971       196653
# 30201  101.085       200960
# 30203  171.017       201573
# 30207   91.019       189486
# 30209  120.042       215280
#
# [36 rows x 23 columns]

# %%
#remove duplicates of songs
spotify = spotify.drop_duplicates(subset=["track_name","track_artist"], keep='first')

# %%
spotify[spotify["track_popularity"]==98]
# Out:
#                     track_id       track_name track_artist  track_popularity  \
# 687   7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 711   2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 716   0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 5508  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
#
#               track_album_id                       track_album_name  \
# 687   7mKevNHhVnZER3BLgI8O4F                                   Tusa
# 711   3nR9B40hYLKLcR0Eph3Goc                               Memories
# 716   2ZfHkwHuoAZrlz7RMj0PDz                        Blinding Lights
# 5508  52u4anZbHd6UInnmHRFzba  Please Excuse Me For Being Antisocial
#
#      track_album_release_date playlist_name             playlist_id  \
# 687                2019-11-07   Todo Éxitos  2ji5tRQVfnhaX1w9FhmSzk
# 711                2019-09-20   Todo Éxitos  2ji5tRQVfnhaX1w9FhmSzk
# 716                2019-11-29   Todo Éxitos  2ji5tRQVfnhaX1w9FhmSzk
# 5508               2019-12-06     RapCaviar  37i9dQZF1DX0XUsuxWHRQd
#
#      playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# 687             pop  ...   2    -3.280     1       0.2980       0.29500
# 711             pop  ...  11    -7.209     1       0.0546       0.83700
# 716             pop  ...   1    -4.075     1       0.0629       0.00147
# 5508            rap  ...  10    -6.687     0       0.0559       0.10400
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 687           0.000134    0.0574    0.574  101.085       200960
# 711           0.000000    0.0822    0.575   91.019       189486
# 716           0.000209    0.0938    0.345  171.017       201573
# 5508          0.000000    0.7900    0.642  116.971       196653
#
# [4 rows x 23 columns]

# %%
# exploring playlists

# %%
set(spotify["playlist_name"])
# Out:
# {'"Permanent Wave"',
#  '10er Playlist',
#  '1987-1997 OLD SKOOL JAMZ',
#  "2000's hard rock",
#  '2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 - 2017 - 2018 - 2019 - 2020 TOP HITS',
#  '2011-2014 House',
#  '2015 songs',
#  '2019 in Indie Poptimism',
#  '2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥',
#  '3rd Coast Classics',
#  "70's Classic Rock",
#  '70s Hard Rock',
#  '70s Pop & Rock Hits and Deep Tracks',
#  "80's Freestyle/Disco Dance Party (Set Crossfade to 4-Seconds)",
#  "80's Songs | Top 💯 80s Music Hits",
#  '80s / Classic Rock',
#  '80s Pop & Rock Hits and Album Tracks',
#  '80s-90s R&B / New Jack Swing / Funk / Dance / Soul',
#  "90's Gangster Rap",
#  "90's Hip Hop Ultimate Collection",
#  "90's NEW JACK SWING",
#  "90's Southern Hip Hop",
#  '90s Dance Hits',
#  '90s Gangsta Rap / Top Hip-hop Classics',
#  '90s Hiphop / Gangsta Rap',
#  '90s R&B - The BET Planet Groove/Midnight Love Mix',
#  '90s-2000s Southern Hip Hop / Crunk',
#  '90s/00s Hip Hop & RnB',
#  '< DARK TRAP >',
#  '@deniceemoberg EDM - POP REMIXES',
#  'A Loose Definition of Indie Poptimism',
#  'A1 Hip-Hop',
#  'ALPAS Music Festival',
#  'Academia Reggaetón',
#  'Afro Psychedelica',
#  'Alex Workout',
#  'Alternative Hip Hop',
#  'Arabic Trap',
#  'Arena Hip-Hop',
#  'BALLARE - رقص',
#  'BIG-ROOM NEVER DIES !',
#  'Back in the day - R&B, New Jack Swing, Swingbeat, RNB..etc.',
#  'Badass Rock',
#  'Baila Reggaeton',
#  'Best of 2019 Dance Pop: Japan',
#  'Best of New Jack Swing',
#  'Big Room 2019',
#  'Big Room Beast',
#  'Big Room EDM',
#  "Big Room EDM - by Spinnin' Records",
#  'Big Room House',
#  'Big Room House / Bigroom',
#  'Big Room House | Festival Bangers',
#  'Big White Room-Jessie-J',
#  'Bluegrass Covers',
#  'Blues Rock',
#  'Bounce United',
#  'Brand New EDM',
#  'Brisa Pop',
#  'CHRISTIAN ELECTRO / DANCE / EDM',
#  'CSR 103:9 (GTA: SA)',
#  'Caifanes La Historia',
#  'Cardio',
#  'Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs',
#  'Chicano Rap',
#  'Chillout & Remixes 💜',
#  'Chixtape 5 - Tory Lanez',
#  'Christian Dance Party',
#  'Christmas Soul',
#  'City Pop 1985 シティーポップ',
#  'Classic Hard Rock',
#  'Classic Rock',
#  'Classic Rock 70s 80s 90s, Rock Classics - 70s Rock, 80s Rock, 90s Rock Rock  Classicos',
#  'Classic Rock Drive',
#  'Classic Rock Greatest Hits',
#  'Classic Rock Legends',
#  'Classic Rock Now',
#  'Classic Rock Playlist.',
#  'Classic Rock Radio',
#  'Classic Rock Retrogamer',
#  'Classic Rock Workout',
#  'Club Mix 2020 🍹',
#  'Coldplay – Ghost Stories (Deluxe Edition)',
#  'Contemporary Hip Hop',
#  'Contemporary Urban',
#  'Crossfit\u200f\u200f\u200b\u200b   \u200d',
#  'Cuban vibes only',
#  'DK rap',
#  'Dance Pop',
#  'Dance Pop Hits',
#  'Dance Pop Tunes',
#  'Dance Pop: Japan',
#  'Dance Room',
#  'Dancefloor Beats',
#  'De Fiesta',
#  'Deep Electronic Music 2020 & Progressive House',
#  'Deep-deep Bubble Pop',
#  'Dirty South Rap Classics by DJ HOTSAUCE',
#  'Dose Trap',
#  "Dr. Q's Prescription Playlist💊",
#  'EDM - pop remixes',
#  'EDM 2019',
#  'EDM 2020 House & Dance',
#  'EDM House & Dance',
#  'EDM Pop',
#  'EDM TROPICAL',
#  'EDM Trap',
#  'EDM/POP',
#  'ELECTRO HOUSE 2020',
#  'ELECTROPOP',
#  'ELECTROPOP EN ESPAÑOL',
#  'ELECTROPOP🐹',
#  'ELETRIC POP & DANCE',
#  'El Ritmo',
#  'Electro House',
#  "Electro House - by Spinnin' Records",
#  'Electro House 2020',
#  'Electro House Top Tracks',
#  'Electro Pop | Electropop',
#  'Electro Posé - Discoveries',
#  'Electro Swing',
#  'Electro Swing Top 100',
#  'Electro Vibes',
#  'Electro/Progressive/Club House',
#  'ElectroPop',
#  'ElectroPop 2020',
#  'Electropop',
#  'Electropop - Pop',
#  'Electropop 2019',
#  'Electropop 80/90s',
#  'Electropop And Play',
#  'Electropop Hits  2017-2020',
#  'Electrónica, Progressive House, Electro House y más 🎧',
#  'Epic Bass Drops',
#  'Epic Bass Drops | Best House Mixes',
#  'Exitos 2020 - Latin Billboard',
#  'F**KIN PERFECT',
#  'Feeling Accomplished',
#  'Female Vocal EDM',
#  'Festival Music 2019 - Warm Up Music (EDM, Big Room & Progressive House)',
#  'Fiesta Latina Mix 🎈🎉💃🏻🕺🏻☀️🏖',
#  'Fitness Workout Electro | House | Dance | Progressive House',
#  'Flow Selecto',
#  'Fresh EDM | Progressive House | Electro House | Trap | Deep House | Electronic | Future House/Bass',
#  'Fresh Essentials',
#  'GANGSTA RAP',
#  'GANGSTA Rap',
#  'GTA San Andreas Radio Los Santos',
#  'GTA V - Radio Mirror Park',
#  'Gangsta Rap 💎 Rap Party',
#  "Gangsta Rap/90's Hip-Hop",
#  'Gangster Rap',
#  'Gangster Rap Deutsch',
#  'Gangster Rap Workout',
#  'Gangster Rap | 100 % Gangster',
#  'Generacja Hip Hop',
#  'Girl On Fire',
#  'Global Top 50 | 2020 Hits',
#  'Global X',
#  'Gospel',
#  'Gospel Neo Soul',
#  'Gothic / Industrial / Mittelalter / EBM / Futurepop / Gothik / Electropop',
#  'Great Pops',
#  'Groovy // Funky // Neo-Soul',
#  'Gym (Melbourne Bounce/Progressive House)',
#  'HARD ROCK CAFE',
#  'HARD ROCK Vibes',
#  'HIP&HOP',
#  "HIP-HOP: Latin Rap ['89-present]",
#  'Hands Up\u200f\u200f\u200b\u200b   \u200d',
#  'Happy EDM',
#  'Hard Rock',
#  'Hard Rock Cafe Classics',
#  'Hard Rock Classics 1967-1991 (Party Edition)',
#  'Hard Rock Workout',
#  'Hard Rock Workout!',
#  'Hip Hop Controller',
#  'Hip Pop 2019',
#  'Hip Te Hop',
#  'Hip pop',
#  "Hip-Hop 'n RnB",
#  'Hip-Hop Central',
#  'Hip-Hop Drive',
#  'Hip-Hop Favourites',
#  'Hip-Hop Mixtape',
#  'Hot Latino Mix (Latin, Hip Hop, Rap, RnB, Dancehall, Reggeaton, Afro)',
#  'House Electro 2019',
#  'House Of The Rising Sun',
#  'House/Electro/Progressive/Disco/Lofi/Synthwave',
#  'I Love My Neo-Soul',
#  'I didn’t know perm stood for permanent (wave)',
#  'INDIE POP! TUNES',
#  'Indie Poptimism',
#  'Indie Poptimism (PUBLIC, The Band CAMINO, lovelytheband)',
#  'Indie Poptimism!',
#  'Indie/Jazz Poptimism',
#  'Intro to Indie Poptimism',
#  'Intro to Permanent Wave',
#  'Intro to Post-Teen Pop',
#  'Japanese Funk/Soul/NEO/Jazz/Acid',
#  'Jazz Vibes',
#  'Jeff Seid Electro House',
#  'K-Crazy Michioso Tunes',
#  'K-Party Dance Mix',
#  "Kenny B's Ultimate New Jack Swing Mix",
#  "L' ALBUM ROCK",
#  'LATIN FLOW MIX - Música Cristiana🎵',
#  'LATIN POP 2020 🔥 Pop latino actual',
#  'LATIN POP- DJ GIAN',
#  'Latest Hits 2020 - Pop, Hip Hop & RnB',
#  'Latest Latin American Hits 2020',
#  'Latin Hip Hop & Rap Playlist 2019',
#  'Latin Hip Hop/Freestyle',
#  'Latin Pop 2019',
#  'Latin Pop Classics',
#  'Latin Pop Rising',
#  'Latin Pop Songs',
#  'Latin Pop VIP',
#  'Latin Pop antiguo',
#  'Latin Village 2019',
#  'Latin/Hip Hop/Dancehall/Soca',
#  'Lo-Fi Beats',
#  'Locker Room',
#  'Lofi Hip-Hop',
#  'Los Cangri',
#  'Lush Lofi',
#  'MIX LATIN POP°',
#  'Mansión Reggaetón',
#  'Maxi Pop  GOLD (New Wave, Electropop, Synth Pop...)',
#  'Mega Rock Ballads: The Best Slow Rock Compilation Ever !',
#  'Mexican Gangsta Rap',
#  'Michael Learns To Rock album',
#  'Minitruckin Playlist',
#  'Mix ElectroPop//ElectroHouse// DeepHouse 2020',
#  'Modern Indie Rock // Alternative Rock / Garage Rock / Pop Punk / Grunge / Britpop / Pop Rock',
#  'Modus Mio',
#  'Most Popular 2020 TOP 50',
#  'Muse Radio - (Uprising, Starlight, Supermassive Black Hole, Madness)',
#  'Music&Other Drugs',
#  'Musica Italiana 2020 - Playlist Pop & Hip-Hop (Canzoni Italiane 2020)',
#  'NEO FUNK AND SOUL',
#  'NEO SOUL GUITAR',
#  'NEO-soul',
#  'Nasty Bits',
#  'Neo Soul',
#  'Neo Soul / Modern Jazz / Smooth Hiphop',
#  'Neo Soul 2019',
#  'Neo Soul Music',
#  'Neo-Jazz Soul RnB & Afro',
#  'Neo-Soul',
#  'Neo-Soul / Soulful R&B',
#  'Neo-Soul Essentials',
#  'Neo-Soul Guitar',
#  'New Hard Rock',
#  'New Hip Hop\u200f\u200f\u200b\u200b   \u200d',
#  'New House   \u200d',
#  'New Jack City',
#  'New Jack Swing',
#  'New Jack Swing - 90s R&B fused w Hip Hop',
#  "New Jack Swing -late 80's & early 90's Hip Hop and R&B",
#  'New Jack Swing | The Best 👌',
#  'New Jack Swing/ R&B Hits: 1987 - 2002',
#  'New R&B\u200f\u200f\u200b\u200b   \u200d',
#  'Nidza Bleja - English HIP HOP/POP Songs',
#  "Nikki Sixx's Top Pixx",
#  'ONE OK ROCK with Orchestra Japan Tour 2018 Setlist',
#  'Oldschool Gangsta Rap 👑',
#  'Orgulho Tropical',
#  'PAROOKAVILLE - Big Room',
#  'POPTIMISM',
#  'PROJECT: Contemporary',
#  'Paraiso Tropical',
#  'Paraíso Tropical',
#  'Permanent Wave',
#  'Permanent Wave CHDB',
#  'Permanent Wave Cafe',
#  'Permanent wave',
#  'Permanent wave 🌊',
#  'Perreo City',
#  'Pinoy Classic Rock',
#  'Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop',
#  'Pop / Dance',
#  'Pop / Hip-Hop: Gas ⛽️',
#  'Pop 2009-2011',
#  'Pop Dance Hits',
#  'Pop EDM',
#  'Pop EDM Remixes',
#  'Pop Hits 2000-2019',
#  'Pop Hits 2020',
#  'Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s',
#  'Pop Latino 2019 - Mix Canciones Reggaeton & Pop Latino - Pop En Español 2019 Musica Para Bailar',
#  'Pop Punk | Post-Hardcore',
#  'Pop Remix',
#  'Pop Warmup 130 BPM',
#  'Post Teen Pop',
#  'Post pop teen',
#  'Post teen pop',
#  'Post-Teen Pop',
#  'Post-teen pop',
#  'Progressive Rock / Metal - Rock /Metal  Progresivo',
#  'Punto Tropical',
#  "R&B 80's/90's/00's",
#  'RADIO POP CHARTS',
#  'RAP 91',
#  'RAP Gangsta',
#  'REGGAETON ANTIGUO 🔥',
#  'REGGAETON VIEJO',
#  'RUSSIAN Gangster Rap',
#  'Rap Party 24/7 Radio / Gangsta Rap',
#  'Rap Workout',
#  'RapCaviar',
#  'Reggaeton 2020 ☀',
#  'Reggaeton 2020 😍 🔥',
#  'Reggaeton Classics',
#  'Reggaeton De Ayer',
#  'Reggaeton Rewind',
#  'Reggaeton viejito🔥',
#  "Rock Ballads 80s 90s | Best Rock Love Songs 80's 90's Music Hits",
#  'Rock Classics',
#  'Rock Hard',
#  'Rock Hubspot',
#  'Rock and Rios',
#  'Russian Gangster Rap',
#  'SINULOG Festival 2020',
#  'SNZB PERMANENT WAVE',
#  'Sad Trap',
#  'Saxophone in Hip Hop - R&B Lounge - Jazz Rap',
#  'School Dance 2019 (Squeaky Clean)',
#  'Selected House',
#  'Sexy Soul 2020',
#  'Sick Big Room House Drops | EZUMI',
#  'Smooth Hip Hop',
#  'Soda Stereo – El Ultimo Concierto',
#  'Soft Rock Drive',
#  'Someone You Loved Lewis Capaldi (Pop Music Mix)',
#  'Soul Coffee (The Best Neo-Soul Mixtape ever)',
#  'Southern California Hip Hop Primer',
#  'Southern Hip Hop',
#  'Southern Rock/Classic Rock',
#  'Southern Soul BBQ Mix',
#  'Southern soul & hip hop',
#  'Sunny Beats',
#  'Supernatural Classic Rock',
#  'Swingbeat (old skool), New Jack Swing, R&B, Hip Hop, Urban',
#  'TOP 50 GLOBAL 2020 UPDATED WEEKLY 🌍🎶 WORLDWIDE',
#  'TROPICAL🌴',
#  'TUNES DANCE AND POP',
#  'Tastemakers Ball  -  EDM - POP and FUN',
#  'Techno House 2020 👽 Best Collection 👻 Top DJ’s Electronic Music - Deep House - Trance - Tech House - Dance - Electro Pop',
#  'The 1950s/1960s/1970s/1980s/1990s/2000s/2010s with pop/r&b/soul/boogie/dance/jazz/hip hop/hop/rap.',
#  'The Black Album',
#  'The Cranberries Best Of',
#  'The Edge of Indie Poptimism',
#  'The New (Jack Swing) Testament',
#  'The Pulse of Indie Poptimism',
#  'The Queen - La Discografia Completa',
#  'The Sound of Album Rock',
#  'The Sound of Indie Poptimism',
#  'The Sound of New Jack Swing',
#  'The Sound of Permanent Wave',
#  'The Sound of Post-Teen Pop',
#  'The Sound of Southern Hip Hop',
#  'The Sound of Urban Contemporary',
#  'This Is Gloria Estefan',
#  "This Is Guns N' Roses",
#  'This Is Janelle Monáe',
#  'This Is Logic',
#  'This Is Scorpions',
#  'This Is: Don Omar',
#  'This Is: Javiera Mena',
#  "Today's Hits (Clean)",
#  "Today's Hits 2000-Present",
#  'Todo Reggaeton',
#  'Todo Éxitos',
#  'Top Urban Underground',
#  'Trance Party 2019 by FUTURE TRANCE',
#  'Trap 2020 🔥',
#  'Trap Americana',
#  'Trap Argentino - Trap Argentina',
#  'Trap Funk',
#  'Trap Land',
#  'Trap Luv',
#  'Trap Mojito',
#  'Trap Nation',
#  'Trap Nation 🔊',
#  'Trap Ouro',
#  'Trap Rewind',
#  'Trap strefa',
#  'Trapperz',
#  'Trapperz Argentina',
#  'Trapperz Brasil',
#  'Trending EDM by Nik Cooper',
#  'Tropical Beats',
#  'Tropical House',
#  'Tropical House 2020',
#  'Tropical House Remixes 🍍 Tropical Remixes & Tropical Covers',
#  'Tropical House Run 190 BPM',
#  'Tropical House 🌴',
#  'Tropical House 🏝 2020 Hits',
#  'Tropical Morning',
#  'Tropical Nights',
#  'Tropical Rising',
#  'Tropical Vibes',
#  'Tusa - Karol G | China - Anuel AA | Estrenos Reggaeton y Música Urbana 2019',
#  'URBAN NATION',
#  'Ultimate Indie Presents... Best Indie Tracks of the 2010s',
#  'Ultimate Indie Presents... Best Tracks of 2019',
#  'Ultimate Throwbacks Collection',
#  'Underground Party | Hypnotic | Minimal | Acid | Big Room | Tech | Liquid',
#  'Unplugged Hits 📣',
#  'Urban Contemporary',
#  'Urban contemporary',
#  'Urban/Trap - Contemporary RAP',
#  'Urbano: Latino Vibes',
#  'Vault: Def Leppard Greatest Hits',
#  'Verano Forever',
#  'Verão 2020 | Pop | Funk | Sertanejo | EDM | Top Hits 2019 - As Mais Tocadas',
#  'Vibra Tropical',
#  'VidaLoca - Latin / Raggaeton / Hip Hop ©',
#  'Viral Southern Hip Hop',
#  'Vocal House',
#  'Waves Pop and EDM',
#  'Workday: Rock Classics',
#  'Workout Hard Rock',
#  'Zona Trap',
#  '[EAS]: Festival Big Room',
#  'a taste of the mainstream',
#  'big boom room — TOMORROWLAND EDC EDM BIG ROOM AMF ADE DANCE TRANCE HARDWELL TIESTO',
#  'indie poptimism',
#  'indie poptimism🕺🏻',
#  'keg party jukebox',
#  'latin hip hop',
#  'permanent wave',
#  'post teen pop',
#  'post-teen alternative, indie, pop (large variety)',
#  'post-teen pop',
#  "random playlist that can't decide its genre so go ahead jam along with these catchy tunes",
#  'urban CONTEMPORARY',
#  'urban contemporary',
#  '’80s Hard Rock',
#  '②⓪①⑨ mixed',
#  '◤ Hip Hop Dance Music – Urban – Trap – Breaking Locking Popping Bopping – WOD – World of Dance',
#  '♥ EDM LOVE 2020',
#  '💊ELECTRO-HOUSE-TECH💊',
#  '🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/2019🔥',
#  "🔥💵 Hip Hop, Rap, Heavy 808's - New School",
#  '🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENNA || BROEDERS || HENKIE T  || BIZZEY || POKE \\\\',
#  '🤩🤪Post Teen Pop🤪🤩'}

# %% [markdown]
# playlist to remove:
#
# 'Coldplay – Ghost Stories (Deluxe Edition)',
# 'Muse Radio - (Uprising, Starlight, Supermassive Black Hole, Madness)',
# 'Someone You Loved Lewis Capaldi (Pop Music Mix)',
# 'This Is Gloria Estefan',
#  "This Is Guns N' Roses",
#  'This Is Janelle Monáe',
#  'This Is Logic',
#  'This Is Scorpions',
#  'This Is: Don Omar',
#  'This Is: Javiera Mena'
#  'Tusa - Karol G | China - Anuel AA | Estrenos Reggaeton y Música Urbana 2019',
#  'Vault: Def Leppard Greatest Hits'

# %%
remove_playlist = ['Coldplay – Ghost Stories (Deluxe Edition)',
'Muse Radio - (Uprising, Starlight, Supermassive Black Hole, Madness)',
'Someone You Loved Lewis Capaldi (Pop Music Mix)',
'This Is Gloria Estefan',
 "This Is Guns N' Roses",
 'This Is Janelle Monáe',
 'This Is Logic',
 'This Is Scorpions',
 'This Is: Don Omar',
 'This Is: Javiera Mena'
 'Tusa - Karol G | China - Anuel AA | Estrenos Reggaeton y Música Urbana 2019',
 'Vault: Def Leppard Greatest Hits']

# %%
spotify = spotify[~spotify['playlist_name'].isin(remove_playlist)]

# %%
set(spotify["playlist_name"])
# Out:
# {'"Permanent Wave"',
#  '10er Playlist',
#  '1987-1997 OLD SKOOL JAMZ',
#  "2000's hard rock",
#  '2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 - 2017 - 2018 - 2019 - 2020 TOP HITS',
#  '2011-2014 House',
#  '2015 songs',
#  '2019 in Indie Poptimism',
#  '2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥',
#  '3rd Coast Classics',
#  "70's Classic Rock",
#  '70s Hard Rock',
#  '70s Pop & Rock Hits and Deep Tracks',
#  "80's Freestyle/Disco Dance Party (Set Crossfade to 4-Seconds)",
#  "80's Songs | Top 💯 80s Music Hits",
#  '80s / Classic Rock',
#  '80s Pop & Rock Hits and Album Tracks',
#  '80s-90s R&B / New Jack Swing / Funk / Dance / Soul',
#  "90's Gangster Rap",
#  "90's Hip Hop Ultimate Collection",
#  "90's NEW JACK SWING",
#  "90's Southern Hip Hop",
#  '90s Dance Hits',
#  '90s Gangsta Rap / Top Hip-hop Classics',
#  '90s Hiphop / Gangsta Rap',
#  '90s R&B - The BET Planet Groove/Midnight Love Mix',
#  '90s-2000s Southern Hip Hop / Crunk',
#  '90s/00s Hip Hop & RnB',
#  '< DARK TRAP >',
#  '@deniceemoberg EDM - POP REMIXES',
#  'A Loose Definition of Indie Poptimism',
#  'A1 Hip-Hop',
#  'ALPAS Music Festival',
#  'Academia Reggaetón',
#  'Afro Psychedelica',
#  'Alex Workout',
#  'Alternative Hip Hop',
#  'Arabic Trap',
#  'Arena Hip-Hop',
#  'BALLARE - رقص',
#  'BIG-ROOM NEVER DIES !',
#  'Back in the day - R&B, New Jack Swing, Swingbeat, RNB..etc.',
#  'Badass Rock',
#  'Baila Reggaeton',
#  'Best of 2019 Dance Pop: Japan',
#  'Best of New Jack Swing',
#  'Big Room 2019',
#  'Big Room Beast',
#  'Big Room EDM',
#  "Big Room EDM - by Spinnin' Records",
#  'Big Room House',
#  'Big Room House / Bigroom',
#  'Big Room House | Festival Bangers',
#  'Big White Room-Jessie-J',
#  'Bluegrass Covers',
#  'Blues Rock',
#  'Bounce United',
#  'Brand New EDM',
#  'Brisa Pop',
#  'CHRISTIAN ELECTRO / DANCE / EDM',
#  'CSR 103:9 (GTA: SA)',
#  'Caifanes La Historia',
#  'Cardio',
#  'Charts 2020 🔥Top 2020🔥Hits 2020🔥Summer 2020🔥Pop 2020🔥Popular Music🔥Clean Pop 2020🔥Sing Alongs',
#  'Chicano Rap',
#  'Chillout & Remixes 💜',
#  'Chixtape 5 - Tory Lanez',
#  'Christian Dance Party',
#  'Christmas Soul',
#  'City Pop 1985 シティーポップ',
#  'Classic Hard Rock',
#  'Classic Rock',
#  'Classic Rock 70s 80s 90s, Rock Classics - 70s Rock, 80s Rock, 90s Rock Rock  Classicos',
#  'Classic Rock Drive',
#  'Classic Rock Greatest Hits',
#  'Classic Rock Legends',
#  'Classic Rock Now',
#  'Classic Rock Playlist.',
#  'Classic Rock Radio',
#  'Classic Rock Retrogamer',
#  'Classic Rock Workout',
#  'Club Mix 2020 🍹',
#  'Contemporary Hip Hop',
#  'Contemporary Urban',
#  'Crossfit\u200f\u200f\u200b\u200b   \u200d',
#  'Cuban vibes only',
#  'DK rap',
#  'Dance Pop',
#  'Dance Pop Hits',
#  'Dance Pop Tunes',
#  'Dance Pop: Japan',
#  'Dance Room',
#  'Dancefloor Beats',
#  'De Fiesta',
#  'Deep Electronic Music 2020 & Progressive House',
#  'Deep-deep Bubble Pop',
#  'Dirty South Rap Classics by DJ HOTSAUCE',
#  'Dose Trap',
#  "Dr. Q's Prescription Playlist💊",
#  'EDM - pop remixes',
#  'EDM 2019',
#  'EDM 2020 House & Dance',
#  'EDM House & Dance',
#  'EDM Pop',
#  'EDM TROPICAL',
#  'EDM Trap',
#  'EDM/POP',
#  'ELECTRO HOUSE 2020',
#  'ELECTROPOP',
#  'ELECTROPOP EN ESPAÑOL',
#  'ELECTROPOP🐹',
#  'ELETRIC POP & DANCE',
#  'El Ritmo',
#  'Electro House',
#  "Electro House - by Spinnin' Records",
#  'Electro House 2020',
#  'Electro House Top Tracks',
#  'Electro Pop | Electropop',
#  'Electro Posé - Discoveries',
#  'Electro Swing',
#  'Electro Swing Top 100',
#  'Electro Vibes',
#  'Electro/Progressive/Club House',
#  'ElectroPop',
#  'ElectroPop 2020',
#  'Electropop',
#  'Electropop - Pop',
#  'Electropop 2019',
#  'Electropop 80/90s',
#  'Electropop And Play',
#  'Electropop Hits  2017-2020',
#  'Electrónica, Progressive House, Electro House y más 🎧',
#  'Epic Bass Drops',
#  'Epic Bass Drops | Best House Mixes',
#  'Exitos 2020 - Latin Billboard',
#  'F**KIN PERFECT',
#  'Feeling Accomplished',
#  'Female Vocal EDM',
#  'Festival Music 2019 - Warm Up Music (EDM, Big Room & Progressive House)',
#  'Fiesta Latina Mix 🎈🎉💃🏻🕺🏻☀️🏖',
#  'Fitness Workout Electro | House | Dance | Progressive House',
#  'Flow Selecto',
#  'Fresh EDM | Progressive House | Electro House | Trap | Deep House | Electronic | Future House/Bass',
#  'Fresh Essentials',
#  'GANGSTA RAP',
#  'GANGSTA Rap',
#  'GTA San Andreas Radio Los Santos',
#  'GTA V - Radio Mirror Park',
#  'Gangsta Rap 💎 Rap Party',
#  "Gangsta Rap/90's Hip-Hop",
#  'Gangster Rap',
#  'Gangster Rap Deutsch',
#  'Gangster Rap Workout',
#  'Gangster Rap | 100 % Gangster',
#  'Generacja Hip Hop',
#  'Girl On Fire',
#  'Global Top 50 | 2020 Hits',
#  'Global X',
#  'Gospel',
#  'Gospel Neo Soul',
#  'Gothic / Industrial / Mittelalter / EBM / Futurepop / Gothik / Electropop',
#  'Great Pops',
#  'Groovy // Funky // Neo-Soul',
#  'Gym (Melbourne Bounce/Progressive House)',
#  'HARD ROCK CAFE',
#  'HARD ROCK Vibes',
#  'HIP&HOP',
#  "HIP-HOP: Latin Rap ['89-present]",
#  'Hands Up\u200f\u200f\u200b\u200b   \u200d',
#  'Happy EDM',
#  'Hard Rock',
#  'Hard Rock Cafe Classics',
#  'Hard Rock Classics 1967-1991 (Party Edition)',
#  'Hard Rock Workout',
#  'Hard Rock Workout!',
#  'Hip Hop Controller',
#  'Hip Pop 2019',
#  'Hip Te Hop',
#  'Hip pop',
#  "Hip-Hop 'n RnB",
#  'Hip-Hop Central',
#  'Hip-Hop Drive',
#  'Hip-Hop Favourites',
#  'Hip-Hop Mixtape',
#  'Hot Latino Mix (Latin, Hip Hop, Rap, RnB, Dancehall, Reggeaton, Afro)',
#  'House Electro 2019',
#  'House Of The Rising Sun',
#  'House/Electro/Progressive/Disco/Lofi/Synthwave',
#  'I Love My Neo-Soul',
#  'I didn’t know perm stood for permanent (wave)',
#  'INDIE POP! TUNES',
#  'Indie Poptimism',
#  'Indie Poptimism (PUBLIC, The Band CAMINO, lovelytheband)',
#  'Indie Poptimism!',
#  'Indie/Jazz Poptimism',
#  'Intro to Indie Poptimism',
#  'Intro to Permanent Wave',
#  'Intro to Post-Teen Pop',
#  'Japanese Funk/Soul/NEO/Jazz/Acid',
#  'Jazz Vibes',
#  'Jeff Seid Electro House',
#  'K-Crazy Michioso Tunes',
#  'K-Party Dance Mix',
#  "Kenny B's Ultimate New Jack Swing Mix",
#  "L' ALBUM ROCK",
#  'LATIN FLOW MIX - Música Cristiana🎵',
#  'LATIN POP 2020 🔥 Pop latino actual',
#  'LATIN POP- DJ GIAN',
#  'Latest Hits 2020 - Pop, Hip Hop & RnB',
#  'Latest Latin American Hits 2020',
#  'Latin Hip Hop & Rap Playlist 2019',
#  'Latin Hip Hop/Freestyle',
#  'Latin Pop 2019',
#  'Latin Pop Classics',
#  'Latin Pop Rising',
#  'Latin Pop Songs',
#  'Latin Pop VIP',
#  'Latin Pop antiguo',
#  'Latin Village 2019',
#  'Latin/Hip Hop/Dancehall/Soca',
#  'Lo-Fi Beats',
#  'Locker Room',
#  'Lofi Hip-Hop',
#  'Los Cangri',
#  'Lush Lofi',
#  'MIX LATIN POP°',
#  'Mansión Reggaetón',
#  'Maxi Pop  GOLD (New Wave, Electropop, Synth Pop...)',
#  'Mega Rock Ballads: The Best Slow Rock Compilation Ever !',
#  'Mexican Gangsta Rap',
#  'Michael Learns To Rock album',
#  'Minitruckin Playlist',
#  'Mix ElectroPop//ElectroHouse// DeepHouse 2020',
#  'Modern Indie Rock // Alternative Rock / Garage Rock / Pop Punk / Grunge / Britpop / Pop Rock',
#  'Modus Mio',
#  'Most Popular 2020 TOP 50',
#  'Music&Other Drugs',
#  'Musica Italiana 2020 - Playlist Pop & Hip-Hop (Canzoni Italiane 2020)',
#  'NEO FUNK AND SOUL',
#  'NEO SOUL GUITAR',
#  'NEO-soul',
#  'Nasty Bits',
#  'Neo Soul',
#  'Neo Soul / Modern Jazz / Smooth Hiphop',
#  'Neo Soul 2019',
#  'Neo Soul Music',
#  'Neo-Jazz Soul RnB & Afro',
#  'Neo-Soul',
#  'Neo-Soul / Soulful R&B',
#  'Neo-Soul Essentials',
#  'Neo-Soul Guitar',
#  'New Hard Rock',
#  'New Hip Hop\u200f\u200f\u200b\u200b   \u200d',
#  'New House   \u200d',
#  'New Jack City',
#  'New Jack Swing',
#  'New Jack Swing - 90s R&B fused w Hip Hop',
#  "New Jack Swing -late 80's & early 90's Hip Hop and R&B",
#  'New Jack Swing | The Best 👌',
#  'New Jack Swing/ R&B Hits: 1987 - 2002',
#  'New R&B\u200f\u200f\u200b\u200b   \u200d',
#  'Nidza Bleja - English HIP HOP/POP Songs',
#  "Nikki Sixx's Top Pixx",
#  'ONE OK ROCK with Orchestra Japan Tour 2018 Setlist',
#  'Oldschool Gangsta Rap 👑',
#  'Orgulho Tropical',
#  'PAROOKAVILLE - Big Room',
#  'POPTIMISM',
#  'PROJECT: Contemporary',
#  'Paraiso Tropical',
#  'Paraíso Tropical',
#  'Permanent Wave',
#  'Permanent Wave CHDB',
#  'Permanent Wave Cafe',
#  'Permanent wave',
#  'Permanent wave 🌊',
#  'Perreo City',
#  'Pinoy Classic Rock',
#  'Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop',
#  'Pop / Dance',
#  'Pop / Hip-Hop: Gas ⛽️',
#  'Pop 2009-2011',
#  'Pop Dance Hits',
#  'Pop EDM',
#  'Pop EDM Remixes',
#  'Pop Hits 2000-2019',
#  'Pop Hits 2020',
#  'Pop Inglés (2020 - 2010s)💙 Música En Inglés 2010s',
#  'Pop Latino 2019 - Mix Canciones Reggaeton & Pop Latino - Pop En Español 2019 Musica Para Bailar',
#  'Pop Punk | Post-Hardcore',
#  'Pop Remix',
#  'Pop Warmup 130 BPM',
#  'Post Teen Pop',
#  'Post pop teen',
#  'Post teen pop',
#  'Post-Teen Pop',
#  'Post-teen pop',
#  'Progressive Rock / Metal - Rock /Metal  Progresivo',
#  'Punto Tropical',
#  "R&B 80's/90's/00's",
#  'RADIO POP CHARTS',
#  'RAP 91',
#  'RAP Gangsta',
#  'REGGAETON ANTIGUO 🔥',
#  'REGGAETON VIEJO',
#  'RUSSIAN Gangster Rap',
#  'Rap Party 24/7 Radio / Gangsta Rap',
#  'Rap Workout',
#  'RapCaviar',
#  'Reggaeton 2020 ☀',
#  'Reggaeton 2020 😍 🔥',
#  'Reggaeton Classics',
#  'Reggaeton De Ayer',
#  'Reggaeton Rewind',
#  'Reggaeton viejito🔥',
#  "Rock Ballads 80s 90s | Best Rock Love Songs 80's 90's Music Hits",
#  'Rock Classics',
#  'Rock Hard',
#  'Rock Hubspot',
#  'Rock and Rios',
#  'Russian Gangster Rap',
#  'SINULOG Festival 2020',
#  'SNZB PERMANENT WAVE',
#  'Sad Trap',
#  'Saxophone in Hip Hop - R&B Lounge - Jazz Rap',
#  'School Dance 2019 (Squeaky Clean)',
#  'Selected House',
#  'Sexy Soul 2020',
#  'Sick Big Room House Drops | EZUMI',
#  'Smooth Hip Hop',
#  'Soda Stereo – El Ultimo Concierto',
#  'Soft Rock Drive',
#  'Soul Coffee (The Best Neo-Soul Mixtape ever)',
#  'Southern California Hip Hop Primer',
#  'Southern Hip Hop',
#  'Southern Rock/Classic Rock',
#  'Southern Soul BBQ Mix',
#  'Southern soul & hip hop',
#  'Sunny Beats',
#  'Supernatural Classic Rock',
#  'Swingbeat (old skool), New Jack Swing, R&B, Hip Hop, Urban',
#  'TOP 50 GLOBAL 2020 UPDATED WEEKLY 🌍🎶 WORLDWIDE',
#  'TROPICAL🌴',
#  'TUNES DANCE AND POP',
#  'Tastemakers Ball  -  EDM - POP and FUN',
#  'Techno House 2020 👽 Best Collection 👻 Top DJ’s Electronic Music - Deep House - Trance - Tech House - Dance - Electro Pop',
#  'The 1950s/1960s/1970s/1980s/1990s/2000s/2010s with pop/r&b/soul/boogie/dance/jazz/hip hop/hop/rap.',
#  'The Black Album',
#  'The Cranberries Best Of',
#  'The Edge of Indie Poptimism',
#  'The New (Jack Swing) Testament',
#  'The Pulse of Indie Poptimism',
#  'The Queen - La Discografia Completa',
#  'The Sound of Album Rock',
#  'The Sound of Indie Poptimism',
#  'The Sound of New Jack Swing',
#  'The Sound of Permanent Wave',
#  'The Sound of Post-Teen Pop',
#  'The Sound of Southern Hip Hop',
#  'The Sound of Urban Contemporary',
#  'This Is: Javiera Mena',
#  "Today's Hits (Clean)",
#  "Today's Hits 2000-Present",
#  'Todo Reggaeton',
#  'Todo Éxitos',
#  'Top Urban Underground',
#  'Trance Party 2019 by FUTURE TRANCE',
#  'Trap 2020 🔥',
#  'Trap Americana',
#  'Trap Argentino - Trap Argentina',
#  'Trap Funk',
#  'Trap Land',
#  'Trap Luv',
#  'Trap Mojito',
#  'Trap Nation',
#  'Trap Nation 🔊',
#  'Trap Ouro',
#  'Trap Rewind',
#  'Trap strefa',
#  'Trapperz',
#  'Trapperz Argentina',
#  'Trapperz Brasil',
#  'Trending EDM by Nik Cooper',
#  'Tropical Beats',
#  'Tropical House',
#  'Tropical House 2020',
#  'Tropical House Remixes 🍍 Tropical Remixes & Tropical Covers',
#  'Tropical House Run 190 BPM',
#  'Tropical House 🌴',
#  'Tropical House 🏝 2020 Hits',
#  'Tropical Morning',
#  'Tropical Nights',
#  'Tropical Rising',
#  'Tropical Vibes',
#  'Tusa - Karol G | China - Anuel AA | Estrenos Reggaeton y Música Urbana 2019',
#  'URBAN NATION',
#  'Ultimate Indie Presents... Best Indie Tracks of the 2010s',
#  'Ultimate Indie Presents... Best Tracks of 2019',
#  'Ultimate Throwbacks Collection',
#  'Underground Party | Hypnotic | Minimal | Acid | Big Room | Tech | Liquid',
#  'Unplugged Hits 📣',
#  'Urban Contemporary',
#  'Urban contemporary',
#  'Urban/Trap - Contemporary RAP',
#  'Urbano: Latino Vibes',
#  'Verano Forever',
#  'Verão 2020 | Pop | Funk | Sertanejo | EDM | Top Hits 2019 - As Mais Tocadas',
#  'Vibra Tropical',
#  'VidaLoca - Latin / Raggaeton / Hip Hop ©',
#  'Viral Southern Hip Hop',
#  'Vocal House',
#  'Waves Pop and EDM',
#  'Workday: Rock Classics',
#  'Workout Hard Rock',
#  'Zona Trap',
#  '[EAS]: Festival Big Room',
#  'a taste of the mainstream',
#  'big boom room — TOMORROWLAND EDC EDM BIG ROOM AMF ADE DANCE TRANCE HARDWELL TIESTO',
#  'indie poptimism',
#  'indie poptimism🕺🏻',
#  'keg party jukebox',
#  'latin hip hop',
#  'permanent wave',
#  'post teen pop',
#  'post-teen alternative, indie, pop (large variety)',
#  'post-teen pop',
#  "random playlist that can't decide its genre so go ahead jam along with these catchy tunes",
#  'urban CONTEMPORARY',
#  'urban contemporary',
#  '’80s Hard Rock',
#  '②⓪①⑨ mixed',
#  '◤ Hip Hop Dance Music – Urban – Trap – Breaking Locking Popping Bopping – WOD – World of Dance',
#  '♥ EDM LOVE 2020',
#  '💊ELECTRO-HOUSE-TECH💊',
#  '🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/2019🔥',
#  "🔥💵 Hip Hop, Rap, Heavy 808's - New School",
#  '🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENNA || BROEDERS || HENKIE T  || BIZZEY || POKE \\\\',
#  '🤩🤪Post Teen Pop🤪🤩'}

# %%
spotify["playlist_genre"].value_counts()
# Out:
# playlist_genre
# rap      5106
# pop      4771
# edm      4603
# r&b      4067
# latin    3742
# rock     3610
# Name: count, dtype: int64

# %%
set(spotify["playlist_subgenre"])
# Out:
# {'album rock',
#  'big room',
#  'classic rock',
#  'dance pop',
#  'electro house',
#  'electropop',
#  'gangster rap',
#  'hard rock',
#  'hip hop',
#  'hip pop',
#  'indie poptimism',
#  'latin hip hop',
#  'latin pop',
#  'neo soul',
#  'new jack swing',
#  'permanent wave',
#  'pop edm',
#  'post-teen pop',
#  'progressive electro house',
#  'reggaeton',
#  'southern hip hop',
#  'trap',
#  'tropical',
#  'urban contemporary'}

# %%
# adding a column for the release year of tracks album

# %%
pattern_year="(^\d{4})"

# %%
spotify["track_album_release_year"]= spotify["track_album_release_date"].str.extract(pattern_year)

# %%
spotify[["track_name","track_artist","track_album_release_date","track_album_release_year"]].sample(10)
# Out:
#                                 track_name             track_artist  \
# 12595   Hanggang Kailan - Umuwi Ka Na Baby          Orange & Lemons
# 15697              House of the Rising Sun  Five Finger Death Punch
# 20671                           Let Her Go                Passenger
# 6933   Gin And Juice (feat. Dat Nigga Daz)               Snoop Dogg
# 5841                         Testing Tubes                  Praizee
# 1846                   I Think I'm In Love               Kat Dahlia
# 6592                                  Yard                 Toddla T
# 8671                                 Жизнь           Andery Toronto
# 26048                            Afro Blue           Robert Glasper
# 17772                              Tu Eres                     Salo
#
#       track_album_release_date track_album_release_year
# 12595               2005-03-24                     2005
# 15697               2013-11-19                     2013
# 20671               2012-06-29                     2012
# 6933                      1993                     1993
# 5841                2019-02-12                     2019
# 1846                2015-01-09                     2015
# 6592                2019-07-05                     2019
# 8671                2017-11-10                     2017
# 26048               2012-01-01                     2012
# 17772               2019-12-13                     2019

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25899 entries, 0 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25899 non-null  object
#  1   track_name                25898 non-null  object
#  2   track_artist              25898 non-null  object
#  3   track_popularity          25899 non-null  int64
#  4   track_album_id            25899 non-null  object
#  5   track_album_name          25898 non-null  object
#  6   track_album_release_date  25899 non-null  object
#  7   playlist_name             25899 non-null  object
#  8   playlist_id               25899 non-null  object
#  9   playlist_genre            25899 non-null  object
#  10  playlist_subgenre         25899 non-null  object
#  11  danceability              25899 non-null  float64
#  12  energy                    25899 non-null  float64
#  13  key                       25899 non-null  int64
#  14  loudness                  25899 non-null  float64
#  15  mode                      25899 non-null  int64
#  16  speechiness               25899 non-null  float64
#  17  acousticness              25899 non-null  float64
#  18  instrumentalness          25899 non-null  float64
#  19  liveness                  25899 non-null  float64
#  20  valence                   25899 non-null  float64
#  21  tempo                     25899 non-null  float64
#  22  duration_ms               25899 non-null  int64
#  23  track_album_release_year  25899 non-null  object
# dtypes: float64(9), int64(4), object(11)
# memory usage: 4.9+ MB

# %%
set(spotify["track_album_release_year"])
# Out:
# {'1957',
#  '1958',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020'}

# %%
# adding a column for the release decade of tracks album

# %%
def decade(year):
    if year<1969:
        return '60s'
    elif year<1979:
        return '70s'
    elif year<1989:
        return '80s'
    elif year<1999:
        return '90s'
    elif year<2009:
        return '2000s'
    elif year<=2020:
        return '2010s'

# %%
spotify["track_album_release_decade"] = pd.to_numeric(spotify["track_album_release_year"]).apply(decade)

# %%
spotify[["track_name","track_artist","track_album_release_date","track_album_release_year","track_album_release_decade"]].sample(10)
# Out:
#                              track_name        track_artist  \
# 7865              Mr. Big Stuff - Remix  Heavy D & The Boyz
# 22625                   Sábanas blancas     Omara Portuondo
# 25736                           Firefly           Mura Masa
# 20913  Mi Dios es grande (feat. T-Bone)       Josue Del Cid
# 1998                       Hungover You          Hazey Eyes
# 10367                         Fake Love       The FifthGuys
# 13990                     Crash into Me  Dave Matthews Band
# 28350                                Ox               SWACQ
# 25790   I Saw Mommy Kissing Santa Claus       The Jackson 5
# 3371                           Enséñame               Morbo
#
#       track_album_release_date track_album_release_year  \
# 7865                1987-10-25                     1987
# 22625               2018-03-25                     2018
# 25736               2015-04-10                     2015
# 20913               2017-05-12                     2017
# 1998                2019-01-30                     2019
# 10367               2019-10-11                     2019
# 13990               1996-04-30                     1996
# 28350               2019-07-03                     2019
# 25790               2009-01-01                     2009
# 3371                2001-01-01                     2001
#
#       track_album_release_decade
# 7865                         80s
# 22625                      2010s
# 25736                      2010s
# 20913                      2010s
# 1998                       2010s
# 10367                      2010s
# 13990                        90s
# 28350                      2010s
# 25790                      2010s
# 3371                       2000s

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25899 entries, 0 to 32832
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track_id                    25899 non-null  object
#  1   track_name                  25898 non-null  object
#  2   track_artist                25898 non-null  object
#  3   track_popularity            25899 non-null  int64
#  4   track_album_id              25899 non-null  object
#  5   track_album_name            25898 non-null  object
#  6   track_album_release_date    25899 non-null  object
#  7   playlist_name               25899 non-null  object
#  8   playlist_id                 25899 non-null  object
#  9   playlist_genre              25899 non-null  object
#  10  playlist_subgenre           25899 non-null  object
#  11  danceability                25899 non-null  float64
#  12  energy                      25899 non-null  float64
#  13  key                         25899 non-null  int64
#  14  loudness                    25899 non-null  float64
#  15  mode                        25899 non-null  int64
#  16  speechiness                 25899 non-null  float64
#  17  acousticness                25899 non-null  float64
#  18  instrumentalness            25899 non-null  float64
#  19  liveness                    25899 non-null  float64
#  20  valence                     25899 non-null  float64
#  21  tempo                       25899 non-null  float64
#  22  duration_ms                 25899 non-null  int64
#  23  track_album_release_year    25899 non-null  object
#  24  track_album_release_decade  25899 non-null  object
# dtypes: float64(9), int64(4), object(12)
# memory usage: 5.1+ MB

# %%
spotify[spotify["track_album_release_decade"]=='60s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 60s    86
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='70s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 70s    638
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='80s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 80s    852
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='90s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 90s    1639
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='2000s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 2000s    3230
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='2010s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 2010s    19720
# Name: count, dtype: int64

# %%
# it would be better to add more songs to the dataframe from 60s, 70s, 80s
set(spotify[spotify["playlist_name"].str.contains('60')]['playlist_name'])
# Out:
# {'The 1950s/1960s/1970s/1980s/1990s/2000s/2010s with pop/r&b/soul/boogie/dance/jazz/hip hop/hop/rap.'}

# %%
set(spotify[spotify["playlist_name"].str.contains('70')]['playlist_name'])
# Out:
# {"70's Classic Rock",
#  '70s Hard Rock',
#  '70s Pop & Rock Hits and Deep Tracks',
#  'Classic Rock 70s 80s 90s, Rock Classics - 70s Rock, 80s Rock, 90s Rock Rock  Classicos',
#  'The 1950s/1960s/1970s/1980s/1990s/2000s/2010s with pop/r&b/soul/boogie/dance/jazz/hip hop/hop/rap.'}

# %%
# adding songs obtained through API

# %%
spotify_more_songs60 = pd.read_csv("../data/spotify_newsongs_60.csv")
spotify_more_songs60
# Out:
#                    track_id                            track_name  \
# 0    7tqhbajSfrz2F7E1Z75ASX         Ain't No Mountain High Enough
# 1    4BP3uh0hFLFRb5cjsgLqDh                         Fortunate Son
# 2    6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 3    63T7DJ1AFDD6Bn8VzG6JE8                       Paint It, Black
# 4    3yrSvpt2l1xhsV9Em88Pul                       Brown Eyed Girl
# ..                      ...                                   ...
# 567  4591VqUIXysNlmI5NcAIUd                                My Guy
# 568  6YTBfxkdGce9pLEy9jG9Jo                         Mais Que Nada
# 569  3c2kMiSB86tVq1J4oULmvL                              Groovin'
# 570  7wLRmjiDYI6flIVzboUqSV        You've Really Got A Hold On Me
# 571  3fnPv1LRMxENr63afVhaz1                      Honky Tonk Women
#
#                      track_artist  track_popularity track_album_release_date  \
# 0      Marvin Gaye, Tammi Terrell                87               1967-08-29
# 1    Creedence Clearwater Revival                87               1969-11-02
# 2                     The Beatles                85               1969-09-26
# 3              The Rolling Stones                85               1966-04-15
# 4                    Van Morrison                83                  1967-09
# ..                            ...               ...                      ...
# 567                    Mary Wells                65                     1964
# 568    Sergio Mendes & Brasil '66                64               1972-01-01
# 569             The Young Rascals                63                     1967
# 570                  The Miracles                62               1963-01-01
# 571            The Rolling Stones                61               2019-11-29
#
#      danceability  energy  valence  track_album_release_year  \
# 0           0.663   0.600    0.800                      1967
# 1           0.640   0.663    0.663                      1969
# 2           0.557   0.540    0.394                      1969
# 3           0.464   0.795    0.612                      1966
# 4           0.491   0.583    0.908                      1967
# ..            ...     ...      ...                       ...
# 567         0.691   0.581    0.910                      1964
# 568         0.637   0.493    0.932                      1972
# 569         0.605   0.455    0.678                      1967
# 570         0.680   0.448    0.567                      1963
# 571         0.560   0.721    0.966                      2019
#
#     track_album_release_decade
# 0                          60s
# 1                          70s
# 2                          70s
# 3                          60s
# 4                          60s
# ..                         ...
# 567                        60s
# 568                        70s
# 569                        60s
# 570                        60s
# 571                      2010s
#
# [572 rows x 10 columns]

# %%
spotify_more_songs = pd.read_csv("../data/more_songs.csv")
spotify_more_songs
# Out:
#                    track_id               track_name  \
# 0    6iPoB3QofIjniCFVyLzO6b             Aanewala Pal
# 1    5ct1ZoLsrjMRsuYMaFN6n3         Chithhi Aayi Hai
# 2    6xCnMMPkIIhn3QyGJgd5xd     Ae Mere Zohra Jabeen
# 3    0C4tVv3KPU8ntwMNnBhek7    Abhi Na Jao Chhod Kar
# 4    6RC3p2RgqBdhL7r7fxhm7s  Kisi Ki Muskurahaton Se
# ..                      ...                      ...
# 651  5eYwDBLucWfWI5KsV7oYX2   Mary Jane's Last Dance
# 652  6H3kDe7CGoWYBabAeVWGiD            Gimme Shelter
# 653  6ztstiyZL6FXzh4aG46ZPD        Boogie Wonderland
# 654  6hTcuIQa0sxrrByu9wTD7s              Born to Run
# 655  0G3fbPbE1vGeABDEZF0jeG               Good Times
#
#                         track_artist  track_popularity  \
# 0                      Kishore Kumar                 0
# 1                 Laxmikant–Pyarelal                 0
# 2              Ravi, Sahir Ludhianvi                56
# 3                      Mohammed Rafi                 0
# 4                             Mukesh                 0
# ..                               ...               ...
# 651  Tom Petty and the Heartbreakers                 0
# 652               The Rolling Stones                79
# 653               Earth, Wind & Fire                79
# 654                Bruce Springsteen                74
# 655                             CHIC                66
#
#     track_album_release_date  playlist_name             playlist_id  \
# 0                       1996  Hindi 60s-70s  7xhJAbAgeZnLy1XeoAhrxh
# 1                 2009-11-30  Hindi 60s-70s  7xhJAbAgeZnLy1XeoAhrxh
# 2                 1965-07-28  Hindi 60s-70s  7xhJAbAgeZnLy1XeoAhrxh
# 3                 2008-01-01  Hindi 60s-70s  7xhJAbAgeZnLy1XeoAhrxh
# 4                 2008-01-01  Hindi 60s-70s  7xhJAbAgeZnLy1XeoAhrxh
# ..                       ...            ...                     ...
# 651               2000-01-01  60 70 80 Hits  39B23QVYhuUK7xJuJUVVbN
# 652               1969-12-05  60 70 80 Hits  39B23QVYhuUK7xJuJUVVbN
# 653                  1979-06  60 70 80 Hits  39B23QVYhuUK7xJuJUVVbN
# 654               1975-08-25  60 70 80 Hits  39B23QVYhuUK7xJuJUVVbN
# 655               1979-07-30  60 70 80 Hits  39B23QVYhuUK7xJuJUVVbN
#
#      danceability  energy  valence
# 0           0.483   0.528    0.636
# 1           0.478   0.763    0.686
# 2           0.441   0.463    0.514
# 3           0.592   0.377    0.550
# 4           0.413   0.452    0.828
# ..            ...     ...      ...
# 651         0.402   0.814    0.516
# 652         0.634   0.630    0.489
# 653         0.802   0.756    0.963
# 654         0.270   0.944    0.606
# 655         0.870   0.657    0.893
#
# [656 rows x 10 columns]

# %%
spotify_more_songs = pd.concat([spotify_more_songs,spotify_more_songs60])

# %%
#clean new dataframe
spotify_more_songs = spotify_more_songs.drop_duplicates(subset=["track_name","track_artist"], keep='first')

# %%
#transform new dataframe
spotify_more_songs["track_album_release_year"]= spotify_more_songs["track_album_release_date"].str.extract(pattern_year)
spotify_more_songs["track_album_release_decade"] = pd.to_numeric(spotify_more_songs["track_album_release_year"]).apply(decade)

# %%
#join the two dataframes
spotify =  pd.concat([spotify,spotify_more_songs], ignore_index=True)

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26991 entries, 0 to 26990
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track_id                    26991 non-null  object
#  1   track_name                  26990 non-null  object
#  2   track_artist                26990 non-null  object
#  3   track_popularity            26991 non-null  int64
#  4   track_album_id              25899 non-null  object
#  5   track_album_name            25898 non-null  object
#  6   track_album_release_date    26991 non-null  object
#  7   playlist_name               26481 non-null  object
#  8   playlist_id                 26481 non-null  object
#  9   playlist_genre              25899 non-null  object
#  10  playlist_subgenre           25899 non-null  object
#  11  danceability                26991 non-null  float64
#  12  energy                      26991 non-null  float64
#  13  key                         25899 non-null  float64
#  14  loudness                    25899 non-null  float64
#  15  mode                        25899 non-null  float64
#  16  speechiness                 25899 non-null  float64
#  17  acousticness                25899 non-null  float64
#  18  instrumentalness            25899 non-null  float64
#  19  liveness                    25899 non-null  float64
#  20  valence                     26991 non-null  float64
#  21  tempo                       25899 non-null  float64
#  22  duration_ms                 25899 non-null  float64
#  23  track_album_release_year    26991 non-null  object
#  24  track_album_release_decade  26968 non-null  object
# dtypes: float64(12), int64(1), object(12)
# memory usage: 5.1+ MB

# %%
spotify[spotify["track_album_release_decade"]=='60s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 60s    414
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='70s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 70s    878
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='80s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 80s    968
# Name: count, dtype: int64

# %%
spotify[spotify["track_album_release_decade"]=='90s']["track_album_release_decade"].value_counts()
# Out:
# track_album_release_decade
# 90s    1758
# Name: count, dtype: int64

# %%
#creating a dataframe for different decades
spotify60 = spotify[pd.to_numeric(spotify["track_album_release_year"])<1970]
spotify70 = spotify[(pd.to_numeric(spotify["track_album_release_year"])>=1970) & (pd.to_numeric(spotify["track_album_release_year"])<1980)]
spotify80 = spotify[(pd.to_numeric(spotify["track_album_release_year"])>=1980) & (pd.to_numeric(spotify["track_album_release_year"])<1990)]
spotify90 = spotify[(pd.to_numeric(spotify["track_album_release_year"])>=1990) & (pd.to_numeric(spotify["track_album_release_year"])<2000)]
spotify00 = spotify[(pd.to_numeric(spotify["track_album_release_year"])>=2000) & (pd.to_numeric(spotify["track_album_release_year"])<2010)]
spotify10 = spotify[(pd.to_numeric(spotify["track_album_release_year"])>=2010) & (pd.to_numeric(spotify["track_album_release_year"])<=2020)]

# %%
#saving new dataframes
spotify60.to_csv("../data/spotify60.csv", index=False)
spotify70.to_csv("../data/spotify70.csv", index=False)
spotify80.to_csv("../data/spotify80.csv", index=False)
spotify90.to_csv("../data/spotify90.csv", index=False)
spotify00.to_csv("../data/spotify00.csv", index=False)
spotify10.to_csv("../data/spotify10.csv", index=False)

# %%
#creating a dataframe with only most popular songs from each decade
spotify_popular = pd.concat([spotify60,spotify70,spotify80,spotify90,spotify00,spotify10], ignore_index=True)

# %%
#saving new dataframe
spotify_popular.to_csv("../data/spotify_popular.csv", index=False)
